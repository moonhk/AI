# %% [markdown]
# <a href="https://colab.research.google.com/github/moonhk/AI/blob/master/Titanic_pytion_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# data파일 업로드 방법
# from google.colab import files
#files.upload()
# 파일 목록 보기
# !ls
# Out:
# gender_submission.csv  sample_data  test.csv  train.csv

# %%
# pandas로 분석하기 좋은 데이터 유형
# 1. SQL 테이블 또는 Excel 시트에서와 같이 열이 있는 형식
# 2. 시계열 데이터
# 3. 행 및 열이 포함된 임의의 행렬 데이터
# pandas로 읽어오기 csv 파일 읽어오기
import pandas as pd
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %%
## 첫 80개 행의 데이터를 보여줍니다.
train.head(80)
# Out:
#     PassengerId  Survived  Pclass  ...      Fare        Cabin  Embarked
# 0             1         0       3  ...    7.2500          NaN         S
# 1             2         1       1  ...   71.2833          C85         C
# 2             3         1       3  ...    7.9250          NaN         S
# 3             4         1       1  ...   53.1000         C123         S
# 4             5         0       3  ...    8.0500          NaN         S
# 5             6         0       3  ...    8.4583          NaN         Q
# 6             7         0       1  ...   51.8625          E46         S
# 7             8         0       3  ...   21.0750          NaN         S
# 8             9         1       3  ...   11.1333          NaN         S
# 9            10         1       2  ...   30.0708          NaN         C
# 10           11         1       3  ...   16.7000           G6         S
# 11           12         1       1  ...   26.5500         C103         S
# ...

# %%
#첫 5개의 행을 보여줌
test.head()
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
# train 차원 정보를 알려줌 ex)(행,열)
train.shape
# Out:
# (891, 12)

# %%
test.shape
# Out:
# (418, 11)

# %%
# 데이터 프레임 자료구조 설명 함수 .info()
# 데이터의 전반적인 구성 및 형태를 파악
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
# 컬럼별 비어있는 칸의 갯수 출력
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# data 시각화 라이브러리
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
# bar_chart(막대그래프) 함수 정의
def bar_chart(feature):
    survived = train[train['Survived']==1][feature].value_counts()
    dead = train[train['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived,dead])
    df.index = ['Survived', 'Dead']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
# 성별 기준으로 생존자수 보여줌
bar_chart('Sex')

# %%
bar_chart('Pclass')

# %%
bar_chart('SibSp')

# %%
bar_chart('Parch')

# %%
bar_chart('Embarked')

# %%
# 이름의 mr,miss, mrs 등을 기준으로 개수셈
train_test_data = [train,test]

for dataset in train_test_data:
    dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\.', expand = False)

# %%
train['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Mlle          2
# Major         2
# Lady          1
# Capt          1
# Don           1
# Ms            1
# Mme           1
# Jonkheer      1
# Sir           1
# Countess      1
# Name: Title, dtype: int64

# %%
train['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Mlle          2
# Major         2
# Lady          1
# Capt          1
# Don           1
# Ms            1
# Mme           1
# Jonkheer      1
# Sir           1
# Countess      1
# Name: Title, dtype: int64

# %%
test['Title'].value_counts()
# Out:
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Col         2
# Rev         2
# Dona        1
# Dr          1
# Ms          1
# Name: Title, dtype: int64

# %%
# Mr : 0, Miss : 1, Mrs, :2 , Others:3 으로 title mapping
title_mapping = {
    "Mr":0,
    "Miss":1,
    "Mrs": 2,
    "Master":4,
    "Dr" : 5,
    "Rev" : 5,
    "Col" : 5,
    "Major" : 5,
    "Mlle" : 5,
    "Countess": 5,
    "Ms" : 5,
    "Lady":5,
    "Jonkheer":5,
    "Don":5,
    "Dona":5,
    "Mme" : 5,
    "Capt" : 5,
    "Sir" : 5
}

for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].map(title_mapping)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  ... Cabin Embarked  Title
# 0            1         0       3  ...   NaN        S      0
# 1            2         1       1  ...   C85        C      2
# 2            3         1       3  ...   NaN        S      1
# 3            4         1       1  ...  C123        S      2
# 4            5         0       3  ...   NaN        S      0
#
# [5 rows x 13 columns]

# %%
# 'Name' 열 제거
train.drop('Name', axis=1, inplace =True)
test.drop('Name',axis=1, inplace=True)

# %%
# 성별 0,1로 설정
sex_mapping = {"male":0, "female": 1}
for dataset in train_test_data:
    dataset['Sex'] = dataset['Sex'].map(sex_mapping)

# %%
bar_chart('Sex')

# %%
# 빈 값 채워줌

# %%
# 'Age' 컬럼의 값으로 평균을 구한 뒤 빈 칸에 값을 채워줌
train["Age"].fillna(train.groupby("Title")["Age"].transform("median"), inplace=True)
test["Age"].fillna(test.groupby("Title")["Age"].transform("median"), inplace=True)

# %%
train.head(30)
train.groupby("Title")["Age"].transform("median")
# Out:
# 0      30.0
# 1      35.0
# 2      21.0
# 3      35.0
# 4      30.0
# 5      30.0
# 6      30.0
# 7       3.5
# 8      35.0
# 9      35.0
# 10     21.0
# 11     21.0
# 12     30.0
# 13     30.0
# 14     21.0
# 15     35.0
# 16      3.5
# 17     30.0
# 18     35.0
# 19     35.0
# 20     30.0
# 21     30.0
# 22     21.0
# 23     30.0
# 24     21.0
# 25     35.0
# 26     30.0
# 27     30.0
# 28     21.0
# 29     30.0
#        ...
# 861    30.0
# 862    35.0
# 863    21.0
# 864    30.0
# 865    35.0
# 866    21.0
# 867    30.0
# 868    30.0
# 869     3.5
# 870    30.0
# 871    35.0
# 872    30.0
# 873    30.0
# 874    35.0
# 875    21.0
# 876    30.0
# 877    30.0
# 878    30.0
# 879    35.0
# 880    35.0
# 881    30.0
# 882    21.0
# 883    30.0
# 884    30.0
# 885    35.0
# 886    44.5
# 887    21.0
# 888    21.0
# 889    30.0
# 890    30.0
# Name: Age, Length: 891, dtype: float64

# %%
for dataset in train_test_data:
  dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0, 
  dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 26), 'Age'] = 1,
  dataset.loc[(dataset['Age'] > 26) & (dataset['Age'] <= 36), 'Age'] = 2,
  dataset.loc[(dataset['Age'] > 36) & (dataset['Age'] <= 62), 'Age'] = 3,
  dataset.loc[ dataset['Age'] > 62, 'Age'] = 4

# %%
Pclass1 = train[train['Pclass']==1]['Embarked'].value_counts()
Pclass2 = train[train['Pclass']==2]['Embarked'].value_counts()
Pclass3 = train[train['Pclass']==3]['Embarked'].value_counts()
df = pd.DataFrame([Pclass1,Pclass2, Pclass3])
df.index=['1st class', '2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].fillna('S')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  ...     Fare  Cabin  Embarked Title
# 0            1         0       3    0  ...   7.2500    NaN         S     0
# 1            2         1       1    1  ...  71.2833    C85         C     2
# 2            3         1       3    1  ...   7.9250    NaN         S     1
# 3            4         1       1    1  ...  53.1000   C123         S     2
# 4            5         0       3    0  ...   8.0500    NaN         S     0
#
# [5 rows x 12 columns]

# %%
embarked_mapping = {"S":0, "C": 1, "Q":2}
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].map(embarked_mapping)

# %%
train["Fare"].fillna(train.groupby("Pclass")["Fare"].transform("median"), inplace=True)
test["Fare"].fillna(train.groupby("Pclass")["Fare"].transform("median"), inplace=True)
train.head(50)
# Out:
#     PassengerId  Survived  Pclass  Sex  ...      Fare        Cabin  Embarked Title
# 0             1         0       3    0  ...    7.2500          NaN         0     0
# 1             2         1       1    1  ...   71.2833          C85         1     2
# 2             3         1       3    1  ...    7.9250          NaN         0     1
# 3             4         1       1    1  ...   53.1000         C123         0     2
# 4             5         0       3    0  ...    8.0500          NaN         0     0
# 5             6         0       3    0  ...    8.4583          NaN         2     0
# 6             7         0       1    0  ...   51.8625          E46         0     0
# 7             8         0       3    0  ...   21.0750          NaN         0     4
# 8             9         1       3    1  ...   11.1333          NaN         0     2
# 9            10         1       2    1  ...   30.0708          NaN         1     2
# ...

# %%
for dataset in train_test_data:
    dataset.loc[ dataset['Fare'] <= 17 , 'Fare'] = 0,
    dataset.loc[(dataset['Fare'] > 17) & (dataset['Fare'] <= 30), 'Fare'] = 1,
    dataset.loc[(dataset['Fare'] > 30) & (dataset['Fare'] <= 100), 'Fare'] =2,
    dataset.loc[ dataset['Fare'] > 100, 'Fare'] == 3

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  ...  Fare  Cabin  Embarked Title
# 0            1         0       3    0  ...   0.0    NaN         0     0
# 1            2         1       1    1  ...   2.0    C85         1     2
# 2            3         1       3    1  ...   0.0    NaN         0     1
# 3            4         1       1    1  ...   2.0   C123         0     2
# 4            5         0       3    0  ...   0.0    NaN         0     0
#
# [5 rows x 12 columns]

# %%
train.Cabin.value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# F2             3
# E101           3
# C22 C26        3
# D              3
# F33            3
# D35            2
# C68            2
# C124           2
# C65            2
# D20            2
# C125           2
# F4             2
# D33            2
# E44            2
# B35            2
# B22            2
# E67            2
# D36            2
# C78            2
# C92            2
# D26            2
# C2             2
# B20            2
# C52            2
# B58 B60        2
# C123           2
# E33            2
#               ..
# B102           1
# C54            1
# A23            1
# B78            1
# B80            1
# E63            1
# B39            1
# C70            1
# E10            1
# T              1
# F38            1
# A5             1
# C99            1
# C106           1
# A16            1
# A24            1
# C148           1
# E38            1
# F G63          1
# E34            1
# D30            1
# ...

# %%
for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].str[:1]

# %%
Pclass1 = train[train['Pclass']==1]['Cabin'].value_counts()
Pclass2 = train[train['Pclass']==2]['Cabin'].value_counts()
Pclass3 = train[train['Pclass']==3]['Cabin'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class', '2nd class', '3rd class']
df.plot(kind='bar', stacked=True, figsize=(10,5))

# %%
cabin_mapping = {
    "A":0,
    "B": 0.4,
    "C" : 0.8,
    "D": 1.2,
    "E":1.6,
    "F": 2,
    "G":2.4,
    "T":2.8
}
for dataset in train_test_data:
  dataset['Cabin'] = dataset['Cabin'].map(cabin_mapping)

# %%
train["Cabin"].fillna(train.groupby("Pclass")["Cabin"].transform("median"), inplace = True)
test["Cabin"].fillna(train.groupby("Pclass")["Cabin"].transform("median"), inplace = True)

# %%
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
test["FamilySize"] = test["SibSp"] + test["Parch"] + 1

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'FamilySize', shade=True)
facet.set(xlim=(0, train['FamilySize'].max()))
plt.xlim(0)
# Out:
# (0, 11.0)

# %%
family_mapping={
    1:0,
    2:0.4,
    3:0.8,
    4:1.2,
    5:1.6,
    6:2,
    7:2.4,
    8:2.8,
    9:3.2,
    10:3.6,
    11:4
}
for dataset in train_test_data:
    dataset['FamilySize'] = dataset['FamilySize'].map(family_mapping)

# %%
features_drop = ['Ticket', 'SibSp', 'Parch']
train = train.drop(features_drop, axis = 1)
test = test.drop(features_drop, axis =1)
train = train.drop(['PassengerId'],axis = 1)

# %%
train_data = train.drop('Survived',axis =1)

# %%
target = train['Survived']

train_data.shape, target.shape
# Out:
# ((891, 8), (891,))

# %%
train_data.head(10)
# Out:
#    Pclass  Sex  Age  Fare  Cabin  Embarked  Title  FamilySize
# 0       3    0  1.0   0.0    2.0         0      0         0.4
# 1       1    1  3.0   2.0    0.8         1      2         0.4
# 2       3    1  1.0   0.0    2.0         0      1         0.0
# 3       1    1  2.0   2.0    0.8         0      2         0.4
# 4       3    0  2.0   0.0    2.0         0      0         0.0
# 5       3    0  2.0   0.0    2.0         2      0         0.0
# 6       1    0  3.0   2.0    1.6         0      0         0.0
# 7       3    0  0.0   1.0    2.0         0      4         1.6
# 8       3    1  2.0   0.0    2.0         0      2         0.8
# 9       2    1  0.0   2.0    1.8         1      2         0.4

# %%
# Importing Classfier Modules
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

import numpy as np

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
# Survived      891 non-null int64
# Pclass        891 non-null int64
# Sex           891 non-null int64
# Age           891 non-null float64
# Fare          891 non-null float64
# Cabin         891 non-null float64
# Embarked      891 non-null int64
# Title         891 non-null int64
# FamilySize    891 non-null float64
# dtypes: float64(4), int64(5)
# memory usage: 62.7 KB

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0 )

# %%
clf = KNeighborsClassifier(n_neighbors=13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.81111111 0.82022472 0.79775281 0.82022472 0.84269663 0.80898876
#  0.86516854 0.79775281 0.82022472 0.82022472]

# %%
# kNN Score
round(np.mean(score)*100, 2)
# Out:
# 82.04

# %%
clf = DecisionTreeClassifier()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.8        0.79775281 0.76404494 0.7752809  0.88764045 0.76404494
#  0.83146067 0.82022472 0.75280899 0.79775281]

# %%
round(np.mean(score)*100,2)
# Out:
# 79.91

# %%
clf = KNeighborsClassifier(n_neighbors=13)
clf.fit(train_data, target)

test_data = test.drop("PassengerId", axis=1).copy()
prediction = clf.predict(test_data)

# %%
submission = pd.DataFrame({
    "PassengerId":test["PassengerId"],
    "Survived":prediction
})

submission.to_csv('submission.csv', index=False)

# %%
submission = pd.read_csv('submission.csv')
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1
